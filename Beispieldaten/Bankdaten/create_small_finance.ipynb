# %%
import pandas as pd

# %%
data = pd.read_csv("finance.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  amount                bookingDate     bookingKey  \
# 0           0  -65.22  2019-10-13 12:00:00+00:00   SDD LASTSCHR
# 1           1  -52.50  2019-10-13 12:00:00+00:00   SDD LASTSCHR
# 2           2  -62.45  2019-10-12 12:00:00+00:00    LASTSCHRIFT
# 3           3  -49.26  2019-10-11 12:00:00+00:00    SEPA ÜBERW.
# 4           4  -78.13  2019-10-10 12:00:00+00:00  KARTENZAHLUNG
#
#                                         cleanPurpose  \
# 0  Kd 1181843 AN 100204621 sie he Gebue hrenbescheid
# 1  Rundfunk 07.XXXX - 09.XXXX Beitrags nr. 473978...
# 2  000 00058 PP.8118.PP . RAKUTEN, Ihr E inkauf b...
# 3  FE5KR5/DE043022019000186671 42 RNR 16041102680...
# 4  DANKE, IHR LIDL//Musterstadt-Wa /DE Terminal 6...
#
#                                creditor   creditorAccountNumber  \
# 0            Stadtreinigung Musterstadt  DE21330500000405205000
# 1             Rundfunk ARD, ZDF, DRadio  DE85370100500123456503
# ...

# %%
data_small = data[["creditor", "debtorAccountNumber", "amount", "bookingDate"]]

# %%
data_small.head()
# Out:
#                                creditor     debtorAccountNumber  amount  \
# 0            Stadtreinigung Musterstadt  DE00999940000000001835  -65.22
# 1             Rundfunk ARD, ZDF, DRadio  DE00999940000000001835  -52.50
# 2  PayPal Europe S.a.r.l. et C ie S.C.A  DE00999940000000001835  -62.45
# 3            Deutsche Internet Apotheke  DE00999940000000001835  -49.26
# 4                       DANKE, IHR LIDL  DE00999940000000001835  -78.13
#
#                  bookingDate
# 0  2019-10-13 12:00:00+00:00
# 1  2019-10-13 12:00:00+00:00
# 2  2019-10-12 12:00:00+00:00
# 3  2019-10-11 12:00:00+00:00
# 4  2019-10-10 12:00:00+00:00

# %%
data_small.loc[0].amount.dtype
# Out:
# dtype('float64')

# %%
data_small.to_csv("finance_small.csv")
